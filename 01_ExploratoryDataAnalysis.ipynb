# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# # 0. Load Data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Load the dataset
df = pd.read_csv('data/raw/cardiovascular_risk_dataset.csv')

# Display the first few rows of the dataset
df.head()
# Out:
#    Patient_ID  age   bmi  systolic_bp  diastolic_bp  cholesterol_mg_dl  \
# 0           1   62  25.0          142            93                247
# 1           2   54  29.7          158           101                254
# 2           3   46  36.2          170           113                276
# 3           4   48  30.4          153            98                230
# 4           5   46  25.3          139            87                206
#
#    resting_heart_rate smoking_status  daily_steps  stress_level  \
# 0                  72          Never        11565             3
# 1                  74        Current         4036             8
# 2                  80        Current         3043             9
# 3                  73         Former         5604             5
# 4                  69        Current         7464             1
#
#    physical_activity_hours_per_week  sleep_hours family_history_heart_disease  \
# ...

# %% [markdown]
# # 1. Data Overview

# %%
# Create Data Dictionary
data_dictionary = pd.DataFrame({
    'Field Name': ["Patient_ID","age", "bmi", "systolic_bp", "diastolic_bp", "cholesterol_mg_dl",
                   "resting_heart_rate", "smoking_status", "daily_steps", "stress_level",
                   "physical_activity_hours_per_week", "sleep_hours", "family_history_heart_disease",
                   "diet_quality_score", "alcohol_units_per_week", "heart_disease_risk_score", "risk_category"],
})

# Add Data Type
data_dictionary['Data Type'] = data_dictionary['Field Name'].apply(lambda x: str(df[x].dtype))

# Add Description
descriptions = {
    "Patient_ID": "Unique identifier for each patient.",
    "age": "Age of the patient in years.",
    "bmi": "Body Mass Index, indicating body fat based on height and weight.",
    "systolic_bp": "Systolic blood pressure level.",
    "diastolic_bp": "Diastolic blood pressure level.",
    "cholesterol_mg_dl": "Total cholesterol level in mg/dL.",
    "resting_heart_rate": "Resting heart rate in beats per minute.",
    "smoking_status": "Smoking category (Never, Former, Current).",
    "daily_steps": "Average number of steps taken per day.",
    "stress_level": "Stress level on a scale from 1 to 10.",
    "physical_activity_hours_per_week": "Weekly hours of physical exercise.",
    "sleep_hours": "Average hours of sleep per night.",
    "family_history_heart_disease": "Indicates whether the patient has a family history of heart disease.",
    "diet_quality_score": "Score (1–10) representing the quality of diet.",
    "alcohol_units_per_week": "Weekly alcohol consumption.",
    "heart_disease_risk_score": "Calculated cardiovascular risk score (0–100).",
    "risk_category": "Risk classification: Low, Medium, or High."
}

data_dictionary['Description'] = data_dictionary['Field Name'].map(descriptions)

data_dictionary
# Out:
#                           Field Name Data Type  \
# 0                         Patient_ID     int64
# 1                                age     int64
# 2                                bmi   float64
# 3                        systolic_bp     int64
# 4                       diastolic_bp     int64
# 5                  cholesterol_mg_dl     int64
# 6                 resting_heart_rate     int64
# 7                     smoking_status    object
# 8                        daily_steps     int64
# 9                       stress_level     int64
# 10  physical_activity_hours_per_week   float64
# 11                       sleep_hours   float64
# 12      family_history_heart_disease    object
# 13                diet_quality_score     int64
# 14            alcohol_units_per_week   float64
# 15          heart_disease_risk_score   float64
# 16                     risk_category    object
#
#                                           Description
# 0                 Unique identifier for each patient.
# ...

# %%
# Get an overview of the dataset

def dataoverview(df, message = "Data Overview"):
    print(f"{message}\n")
    print("\nNumber of rows: ", df.shape[0])
    print("\nNumber of columns: ", df.shape[1])
    print("\nColumns: ", df.columns.tolist())
    print("\nMissing values: ", df.isnull().sum().values.sum())    
    print("\nDuplicate rows: ", df.duplicated().sum())
    print("\nUnique values: \n", df.nunique())
    print("\nData Types: \n", df.dtypes)

dataoverview(df)
# Out:
# Data Overview
#
#
# Number of rows:  5500
#
# Number of columns:  17
#
# Columns:  ['Patient_ID', 'age', 'bmi', 'systolic_bp', 'diastolic_bp', 'cholesterol_mg_dl', 'resting_heart_rate', 'smoking_status', 'daily_steps', 'stress_level', 'physical_activity_hours_per_week', 'sleep_hours', 'family_history_heart_disease', 'diet_quality_score', 'alcohol_units_per_week', 'heart_disease_risk_score', 'risk_category']
#
# Missing values:  0
#
# Duplicate rows:  0
#
# Unique values:
#  Patient_ID                          5500
# age                                   73
# bmi                                  232
# systolic_bp                           82
# diastolic_bp                          55
# cholesterol_mg_dl                    166
# resting_heart_rate                    41
# smoking_status                         3
# daily_steps                         4211
# stress_level                          10
# physical_activity_hours_per_week     123
# sleep_hours                           61
# ...

# %% [markdown]
# **Findings**:
# - There are 17 columns with 5500 rows.
# - 5500 unique Patient IDs, so no duplicates
# - Data types fit the columns, no further cleaning required

# %% [markdown]
# ## 1.1 Target Variable Analysis

# %%
# Define the target variable
target_column = 'risk_category' 

# Describe the target variable
print(f"Target Variable: {target_column}\n")
print(df[target_column].describe())
print("\nValue Counts:\n", df[target_column].value_counts())
# Out:
# Target Variable: risk_category
#
# count       5500
# unique         3
# top       Medium
# freq        2244
# Name: risk_category, dtype: object
#
# Value Counts:
#  risk_category
# Medium    2244
# Low       1838
# High      1418
# Name: count, dtype: int64

# %%
risk_order = ['Low', 'Medium', 'High']
risk_palette = {'Low': "#cbcffaff", 'Medium': "#6291ff", 'High': "#0400ff"} 

plt.figure(figsize=(6, 4))
sns.countplot(
    x=target_column,
    data=df,
    order=risk_order,
    palette=risk_palette  # seaborn uses x categories here
)
plt.title('Distribution of Target Variable')
plt.xlabel('Risk Category')
plt.ylabel('Count')
plt.tight_layout()
plt.show()

# %%
# Risk score to Risk categories
df_group_risk = df.groupby('heart_disease_risk_score')['risk_category'].first().reset_index()

# Range low risk
print("Low risk from: ", df_group_risk[df_group_risk['risk_category'] == 'Low']['heart_disease_risk_score'].max())

# Range medium risk
print("Medium risk up to: ", df_group_risk[df_group_risk['risk_category'] == 'Medium']['heart_disease_risk_score'].max())

#Range high risk
print("High risk from: ", df_group_risk[df_group_risk['risk_category'] == 'High']['heart_disease_risk_score'].min())
# Out:
# Low risk from:  24.9
# Medium risk up to:  54.9
# High risk from:  55.0

# %% [markdown]
# ## 1.2 Numerical Features Analysis

# %%
# Display summary statistics for numerical columns
print(df.describe().T)
# Out:
#                                    count         mean          std    min  \
# Patient_ID                        5500.0  2750.500000  1587.857571    1.0
# age                               5500.0    53.872000    21.196017   18.0
# bmi                               5500.0    28.170818     4.189877   15.0
# systolic_bp                       5500.0   147.248182    13.222701  108.0
# diastolic_bp                      5500.0    95.756727     9.451559   64.0
# cholesterol_mg_dl                 5500.0   239.684182    28.570177  147.0
# resting_heart_rate                5500.0    74.075091     6.392166   48.0
# daily_steps                       5500.0  5902.929455  3041.084590  500.0
# stress_level                      5500.0     4.907091     2.298173    1.0
# physical_activity_hours_per_week  5500.0     3.299364     2.672457    0.0
# sleep_hours                       5500.0     6.869364     1.091263    4.0
# diet_quality_score                5500.0     5.162909     2.286134    1.0
# ...

# %%
# Separate numerical and categorical features
numerical_cols = df.select_dtypes(include=['int64', 'float64']).columns.tolist()
categorical_cols = df.select_dtypes(include=['object', 'category', 'string']).columns.tolist()

print(f"Numerical features ({len(numerical_cols)}): {numerical_cols}")
print(f"Categorical features ({len(categorical_cols)}): {categorical_cols}")

# Distribution of numerical features (grid of histograms)
df[numerical_cols].hist(bins=30, figsize=(15, 10), color='lightblue', edgecolor='black')
plt.suptitle('Distribution of Numerical Features', fontsize=16, fontweight='bold')
plt.tight_layout()
plt.show()
# Out:
# Numerical features (14): ['Patient_ID', 'age', 'bmi', 'systolic_bp', 'diastolic_bp', 'cholesterol_mg_dl', 'resting_heart_rate', 'daily_steps', 'stress_level', 'physical_activity_hours_per_week', 'sleep_hours', 'diet_quality_score', 'alcohol_units_per_week', 'heart_disease_risk_score']
# Categorical features (3): ['smoking_status', 'family_history_heart_disease', 'risk_category']

# %% [markdown]
# **Findings**:
#
# The following features are well distributed (approximately normal):
# - BMI: Nice bell curve centered around 30, range ~15-40
# - Systolic BP: Normal distribution, centered ~145-150, range 110-190
# - Diastolic BP: Normal distribution, centered ~90-100, range 65-120
# - Cholesterol: Fairly normal, centered ~240, range 150-330
# - Resting Heart Rate: Fairly normal, centered ~75, range 50-95
# - Sleep Hours: Normal distribution, centered ~7 hours
# - Diet Quality Score: Relatively uniform
#
# Features requiring transformation:
# - Daily Steps:  Right-skewed with peak at 3,000-5,000 steps, long tail extending to >15,000. Most people live relatively inactive lives. (log/sqrt transformation)
# - Physical Activity Hours per Week: Heavily right-skewed with most observations at 0-2 hours, few outliers at 10+ hours. (log transformation)
# - Alcohol Units per Week: Very heavily right-skewed with most observations at 0-5 units, long tail to ~30 units. (log transformation or binning)
#
# Other notes:
# - Age: Uniform distribution across range
# - Patient_ID: Sequential identifier. Will be dropped before modeling.

# %% [markdown]
# ## 1.3 Categorical Features Analysis

# %%
# Peek at categorical features
print(f"Number of categorical features: {len(categorical_cols)}")
print(f"Categorical columns: {categorical_cols}")
# Out:
# Number of categorical features: 3
# Categorical columns: ['smoking_status', 'family_history_heart_disease', 'risk_category']

# %%
smoking_order = ['Former', 'Current', 'Never']
smoking_palette = {'Never': "#cbcffaff", 'Former':  "#6291ff", 'Current':"#0400ff"}

plt.figure(figsize=(6, 4))
sns.countplot(
    data=df,
    x='smoking_status',
    order=smoking_order,
    palette=smoking_palette,
    edgecolor='black'
)

plt.title('Distribution of Smoking Status')
plt.xlabel('Smoking Status')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Family history of heart disease
print(df['family_history_heart_disease'].value_counts())

# Pie Chart Visualization
plt.figure(figsize=(6,6))
plt.pie(df['family_history_heart_disease'].value_counts(), labels=df['family_history_heart_disease'].value_counts().index, autopct='%1.1f%%', colors=[ "#97e8ff",  "#0040ff"])
plt.title('Family History of Heart Disease')
plt.show()
# Out:
# family_history_heart_disease
# No     4134
# Yes    1366
# Name: count, dtype: int64

# %% [markdown]
# ### 1.3.1 Relationship of Categorical values with Target variable

# %%
# Proportions
smoking_risk_props = pd.crosstab(
    df['smoking_status'],
    df['risk_category'],
    normalize='index'
) * 100

print("\nRisk Distribution by Smoking Status (%):")
print(smoking_risk_props.round(1))


# Plot Distribution of Risk Categories by Smoking Status

smoking_risk_props = smoking_risk_props.reindex(columns=risk_order, fill_value=0)

# Make sure palette matches that order
colors = [risk_palette[c] for c in smoking_risk_props.columns]

ax = smoking_risk_props.plot(
    kind='bar',
    figsize=(8, 6),
    edgecolor='black',
    color=colors,
)

ax.set_title('Smoking Status vs Risk Category (Proportions)')
ax.set_xlabel('Smoking Status')
ax.set_ylabel('Percentage (%)')
ax.set_ylim(0, 100)
ax.set_yticks(np.arange(0, 101, 10))
ax.tick_params(axis='x', rotation=45)
ax.legend(title='Risk Category')

plt.tight_layout()
plt.show()
# Out:
# Risk Distribution by Smoking Status (%):
# risk_category   High   Low  Medium
# smoking_status
# Current         56.5   5.9    37.5
# Former          28.8  24.8    46.4
# Never           16.6  43.0    40.3

# %%
# Proportions
family_history_risk_props = pd.crosstab(
    df['family_history_heart_disease'],
    df['risk_category'],
    normalize='index'
) * 100


print("\nRisk Distribution by Family History of Heart Disease (%):")
print(family_history_risk_props.round(1))

# Plot Distribution of Risk Categories by Family History of Heart Disease

family_history_risk_props = family_history_risk_props.reindex(columns=risk_order, fill_value=0)

ax = family_history_risk_props.plot(
    kind='bar',
    figsize=(6, 4),
    edgecolor='black',
    color=[risk_palette[c] for c in family_history_risk_props.columns],
)

ax.set_title('Family History of Heart Disease vs Risk Category (Proportions)')
ax.set_xlabel('Family History of Heart Disease')
ax.set_ylabel('Percentage (%)')
ax.set_ylim(0, 100)
ax.set_yticks(np.arange(0, 101, 10))
ax.tick_params(axis='x', rotation=0)
ax.legend(title='Risk Category')

plt.tight_layout()
plt.show()
# Out:
# Risk Distribution by Family History of Heart Disease (%):
# risk_category                 High   Low  Medium
# family_history_heart_disease
# No                            22.8  36.6    40.7
# Yes                           34.9  23.9    41.2

# %% [markdown]
# ## 1.4 Correlation Analysis

# %%
# Correlation matrix
plt.figure(figsize=(10, 8))
sns.heatmap(df[numerical_cols].corr(), annot=True, fmt=".2f", cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix of Numerical Features', fontsize=14)
plt.show()


# Encode risk category (ordinal)
risk_encoding = {'Low': 0, 'Medium': 1, 'High': 2}
df_corr = df.copy()
df_corr['risk_category_encoded'] = df_corr['risk_category'].map(risk_encoding)

# Numeric feature matrix
X_num = df_corr[numerical_cols]

# Correlation with risk category
corr_risk_category = X_num.corrwith(df_corr['risk_category_encoded'], method='spearman').dropna()

# Sort (by absolute correlation, so strongest relationships appear first)
corr_risk_category = corr_risk_category.reindex(corr_risk_category.abs().sort_values(ascending=False).index)

# Plot
y = np.arange(len(corr_risk_category))
fig, ax = plt.subplots(figsize=(9, max(4, 0.35 * len(corr_risk_category))))
ax.barh(y, corr_risk_category.values, color= "#ff5050ff", edgecolor='black', alpha=0.85)
ax.set_yticks(y)
ax.set_yticklabels(corr_risk_category.index)
ax.axvline(0, color='black', linestyle='--', linewidth=1)
ax.set_xlabel('Correlation with Risk Category (encoded)')
ax.set_title('Numeric Feature Correlations with Risk Category')
ax.grid(True, axis='x', alpha=0.3)
plt.tight_layout()
plt.show()


# Print top positive and negative correlations with target
correlations_risk_score = df[numerical_cols].corr()['heart_disease_risk_score'].sort_values(ascending=False)
print("Top 5 features positively correlated with Risk Score: \n -----------------------")
print(correlations_risk_score.head(10))
print("\nTop 5 features negatively correlated with Risk Score: \n -----------------------")
print(correlations_risk_score.tail(10))
# Out:
# Top 5 features positively correlated with Risk Score:
#  -----------------------
# heart_disease_risk_score    1.000000
# systolic_bp                 0.901038
# cholesterol_mg_dl           0.852483
# diastolic_bp                0.813140
# bmi                         0.713077
# age                         0.694286
# resting_heart_rate          0.428760
# stress_level                0.377445
# alcohol_units_per_week      0.289130
# Patient_ID                 -0.021508
# Name: heart_disease_risk_score, dtype: float64
#
# Top 5 features negatively correlated with Risk Score:
#  -----------------------
# bmi                                 0.713077
# age                                 0.694286
# resting_heart_rate                  0.428760
# stress_level                        0.377445
# alcohol_units_per_week              0.289130
# Patient_ID                         -0.021508
# sleep_hours                        -0.105379
# daily_steps                        -0.478631
# ...

# %% [markdown]
# ## 1.5 Bivariate Analysis

# %% [markdown]
# Based on the results of the correlation matrix, a bivariate analysis will be performed on the most highly correlated features to further explore their relationship with the risk score.

# %%
# Systolic blood pressure vs Risk Category Scatter Plot
plt.figure(figsize=(8, 6))
sns.scatterplot(
    data=df,
    x='systolic_bp',
    y='heart_disease_risk_score',
    hue='risk_category',
    hue_order=['Low', 'Medium', 'High'],   # or ['High','Medium','Low'] if you prefer
    palette=risk_palette,
    alpha=0.7
)

plt.title('Systolic Blood Pressure vs Risk Score by Risk Category')
plt.xlabel('Systolic Blood Pressure')
plt.ylabel('Heart Disease Risk Score')
plt.legend(title='Risk Category')
plt.tight_layout()
plt.show()

# %%
# Cholesterol vs Risk Category Scatter Plot
plt.figure(figsize=(8, 6))
sns.scatterplot(
    data=df,
    x='cholesterol_mg_dl',
    y='heart_disease_risk_score',
    hue='risk_category',
    hue_order=['Low', 'Medium', 'High'],   # or ['High','Medium','Low'] if you prefer
    palette=risk_palette,
    alpha=0.7
)
plt.title('Cholesterol vs Risk Score by Risk Category')
plt.xlabel('Cholesterol')
plt.ylabel('Heart Disease Risk Score')
plt.legend(title='Risk Category')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Outlier Detection

# %%
# Detect outliers

print(f"{'Column':<40} {'Outliers':>10} {'Percentage':>12}")
print("-" * 70)

outlier_info = {}

for col in numerical_cols:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1

    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR

    is_outlier = (df[col] < lower) | (df[col] > upper)
    n_outliers = is_outlier.sum()
    pct = (n_outliers / len(df)) * 100

    outlier_info[col] = {"lower": lower, "upper": upper, "n": n_outliers, "pct": pct}
    print(f"{col:<40} {n_outliers:>10} {pct:>11.2f}%")

# Remove outliers
mask = pd.Series(True, index=df.index) 

for col, info in outlier_info.items():
    mask &= (df[col] >= info["lower"]) & (df[col] <= info["upper"])

df_clean = df[mask].reset_index(drop=True)

print(f"\nRows before removal : {len(df)}")
print(f"Rows after removal  : {len(df_clean)}")
print(f"Rows removed        : {len(df) - len(df_clean)} "
      f"({(len(df) - len(df_clean)) / len(df) * 100:.2f}%)")
# Out:
# Column                                     Outliers   Percentage
# ----------------------------------------------------------------------
# Patient_ID                                        0        0.00%
# age                                               0        0.00%
# bmi                                               9        0.16%
# systolic_bp                                      15        0.27%
# diastolic_bp                                      5        0.09%
# cholesterol_mg_dl                                 7        0.13%
# resting_heart_rate                               17        0.31%
# daily_steps                                      21        0.38%
# stress_level                                      0        0.00%
# physical_activity_hours_per_week                 42        0.76%
# sleep_hours                                      81        1.47%
# diet_quality_score                                0        0.00%
# ...

# %% [markdown]
# ## 1.7 Key Insights & Hypotheses
# The exploratory data analysis revealed significant patterns that seem to align with established cardiovascular research and serve as a starting point for the subsequent modeling phase.
#
# 1) **Traditional clinical indicators**, such as systolic and diastolic blood pressure, cholesterol levels, and BMI, show a positive association with heart attack risk. In particular, elevated blood pressure and cholesterol levels are frequently observed among high-risk cases. This suggest that the combinated effect of multiple cardiovascular stress factors may translate into a spike in risk probability, highlighting the importance of capturing interaction effects between the variables.
#
# 2) **Lifestyle-related variables**, including smoking habits, alcohol consumption, physical activity, sleep patterns, and daily step counts, display different patterns across risk groups. These findings indicate that, alongside clinical indicators, behavioral factors can play a significant role in predicting cardiovascular events. Additionally, these findings and the relationships among these variables suggest the potential presence of multicollinearity, which should be carefully addressed while developing the models.
#
# Based on these findings, several hypotheses can be formulated prior to the modeling stage:
#
# - Clinical cardiovascular indicators are expected to be primary predictors of heart attack risk.
#
# - Interaction-based or derived features may improve predictive performance by capturing combined risk effects that individual variables may not fully reflect.
#
# - Lifestyle variables are likely to contribute significantly to the explanatory power of the models.
#
# These hypotheses will be subsequentely tested in the modeling phase.
