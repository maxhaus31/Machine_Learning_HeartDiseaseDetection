# %% [markdown]
# # 3. Modeling

# %% [markdown]
# ## 3.1 Baseline Models

# %%
# Pre-processing & pipeline with only original columns

# %%
# Logistic regression Baseline model

# %%
# Random Forest Baseline Model

# %%
# Gradient boosting baseline model

# %% [markdown]
# ## 3.2 Feature engineered Models

# %% [markdown]
# ### 3.2.1 Logistic regression

# %% [markdown]
# ### 3.2.2 Random Forest

# %% [markdown]
# ### 3.2.3 Gradient Boosting (XGBoost)

# %% [markdown]
# ## 3.3 Hyperparameter Tuning
# GridSearch

# %% [markdown]
# ### 3.3.1 Logistic regression

# %% [markdown]
# ### 3.3.2 Random Forest

# %% [markdown]
# ### 3.3.3 Gradient Boosting (XGBoost)
